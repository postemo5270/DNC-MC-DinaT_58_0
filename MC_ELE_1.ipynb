# %% [markdown]
# <a href="https://colab.research.google.com/github/postemo5270/DNC-MC-DinaT_58_0/blob/main/MC_ELE_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# =============================================================================
# LANZADOR MAESTRO (SOLO CONEXIÓN Y CARGA DE DATOS)
# =============================================================================
import sys
import os

# 1. Configuración
REPO_NAME = 'DNC-MC-DinaT_58_0'
USER = 'postemo5270'
URL_REPO = f'https://github.com/{USER}/{REPO_NAME}.git'

# 2. Descarga Limpia
if os.path.exists(REPO_NAME):
    # !rm -rf {REPO_NAME}

print(f"⬇️ Conectando con GitHub...")
# !git clone {URL_REPO} > /dev/null 2>&1

# 3. Carga del Sistema
sys.path.append(f'/content/{REPO_NAME}')

try:
    # Cargamos el Backend automáticamente
    import backend
    print("✅ SISTEMA CONECTADO. Cerebro (Backend) cargado.")
    print("👉 Para abrir Conductores, crea una nueva celda y ejecuta: from ModConds import iniciar_interfaz; iniciar_interfaz()")

except ImportError as e:
    print(f"❌ Error de Conexión: {e}")
# Out:
# ⬇️ Conectando con GitHub...
# ✅ SISTEMA CONECTADO. Cerebro (Backend) cargado.
# 👉 Para abrir Conductores, crea una nueva celda y ejecuta: from ModConds import iniciar_interfaz; iniciar_interfaz()
